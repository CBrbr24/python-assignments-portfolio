# %%
import numpy as np
import matplotlib.pyplot as plt



def normal_density(mean, variance, x):
    calcx = (1/(np.sqrt(2*np.pi*variance)))*(np.e**((-(x - mean)**2)/(2*variance)))
    return calcx


def integration(mean, variance, a,b):
    h = (b - a) / 10
    value = 0.5 * ((normal_density(mean, variance, a)) + (normal_density(mean, variance, b)))
    for i in range(1, 10):
        value += (normal_density(mean, variance, (a+i*h)))
    value *= h
    return value


#print(integration(171,(7.1**2),162,190))


def dist(x,a,b):
    if a <= x <= b:
        return 1/(b-a)
    else:
        return 0
    
def C(x):
    
    return()

def E(a,b):
  
    h = 10
    value2 = 0.5*((dist(a,a,b)*C(a))+(dist(b,a,b)*C(b)))
    for i in range(1, 10):
        value2 += (dist((a + i * h), a, b) * C((a + i * h)))
        
    value2 *= h
    return value2


    



x = [1,1,2,3,4,6]
y = [4,5,2,2,2,3]
z = [5,6,2,3,3,4]

f_function = [normal_density(mean, variance, xi) for mean, variance, xi in zip(x, y, z)]

#print(normal_density(1,1,2))
#plt.plot(x, f_function)
# Out:
# 0.8904790568363015

# %%
def dist(x,a,b):
    if a <= x <= b:
        return 1/(b-a)
    else:
        return 0
    
def C(x):
    
    return()

def E(a,b):
  
    h = 10
    value2 = 0.5*((dist(a,a,b)*C(a))+(dist(b,a,b)*C(b)))
    for i in range(1, 10):
        value2 += (dist((a + i * h), a, b) * C((a + i * h)))
        
    value2 *= h
    return value2

# %%
def dist(x,lamda):
    if x >= 0:
        return lamda*(np.e ** (-lamda * x))
    else:
        return 0
    
def C(x, lamda):
    if x >= 0:
        return 1 - np.exp(-lamda * x)
    else:
        return 0


def E(a,b,lamda):
  
    h = 10
    value2 = 0.5*((dist(a,lamda)*C(a, lamda))+(dist(b,lamda)*C(b, lamda)))
    for i in range(a, b):
        value2 += (dist((a + i * h), lamda) * C((a + i * h), lamda))
        
    value2 *= h
    return value2

print (E(1, 100, (1/50)))

# %%
def normal_density(mean, variance, x):
    calcx = (1/(np.sqrt(2*np.pi*variance)))*(np.e**((-(x - mean)**2)/(2*variance)))
    return calcx


def integration(mean, variance, a,b):
    h = (b - a) / 10
    value = 0.5 * ((normal_density(mean, variance, a)) + (normal_density(mean, variance, b)))
    for i in range(1, 10):
        value += (normal_density(mean, variance, (a+i*h)))
    value *= h
    return value


#print(integration(171,(7.1**2),162,190))



x = [1,1,2,3,4,6]
y = [4,5,2,2,2,3]
z = [5,6,2,3,3,4]

f_function = [normal_density(mean, variance, xi) for mean, variance, xi in zip(x, y, z)]

#print(normal_density(1,1,2))
#plt.plot(x, f_function)


def dosage(mean, variance, a, b):
    hold_value = integration(mean, variance, a, b)
    dos_res = (hold_value ** 2) * 2.38
    return dos_res

    
    
print(dosage(171,(7.1**2),162,190))
